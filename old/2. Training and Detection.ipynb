# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'model_for_TFT' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotation'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'labelimg'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}
# Out:
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !sudo apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Processing /home/n0name/projects/TFT/Tensorflow/models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: avro-python3 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (2.49.0)
# Requirement already satisfied: pillow in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (10.0.0)
# Requirement already satisfied: lxml in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (4.9.3)
# Requirement already satisfied: matplotlib in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (3.7.2)
# Requirement already satisfied: Cython in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (3.0.0)
# Requirement already satisfied: contextlib2 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (2.0.6)
# Requirement already satisfied: lvis in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (1.11.1)
# Requirement already satisfied: pandas in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (2.0.3)
# Requirement already satisfied: tf-models-official>=2.5.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (2.13.1)
# Requirement already satisfied: tensorflow_io in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (0.33.0)
# Requirement already satisfied: keras in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (2.13.1)
# Requirement already satisfied: pyparsing==2.4.7 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: portalocker in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.7.0)
# Requirement already satisfied: regex in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2023.8.8)
# Requirement already satisfied: tabulate>=0.8.9 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.24.3)
# Requirement already satisfied: colorama in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: gin-config in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.96.0)
# Requirement already satisfied: immutabledict in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (3.0.0)
# Requirement already satisfied: kaggle>=1.3.9 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.16)
# Requirement already satisfied: oauth2client in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.8.0.76)
# Requirement already satisfied: psutil>=5.4.3 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml<5.4.0,>=5.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.3.1)
# Requirement already satisfied: sentencepiece in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.1.99)
# Requirement already satisfied: seqeval in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow-datasets in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.2)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.14.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.7.5)
# Requirement already satisfied: tensorflow-text~=2.13.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.13.0)
# Requirement already satisfied: tensorflow~=2.13.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2023.3)
# Requirement already satisfied: absl-py>=0.2.2 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: orjson<4.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (3.9.4)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.8.2)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.18)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.57.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.7.2)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.6.1)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (4.4.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.22.3)
# Requirement already satisfied: protobuf<4.24.0,>=3.20.3 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (11.0.0)
# Requirement already satisfied: cycler>=0.10.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from lvis->object-detection==0.1) (4.8.0.76)
# Requirement already satisfied: contourpy>=1.0.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (4.42.0)
# Requirement already satisfied: packaging>=20.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (6.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.33.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow_io->object-detection==0.1) (0.33.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: docopt in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->object-detection==0.1) (3.16.2)
# Requirement already satisfied: certifi in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2023.7.22)
# Requirement already satisfied: tqdm in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.66.1)
# Requirement already satisfied: python-slugify in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: urllib3 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.16)
# Requirement already satisfied: bleach in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.0.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1) (2.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: astunparse>=1.6.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (68.0.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.15.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.3.0)
# Requirement already satisfied: array-record in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.4.1)
# Requirement already satisfied: click in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.6)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.4.1)
# Requirement already satisfied: promise in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /home/n0name/miniconda3/envs/tft/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1
efficientnet_model.py:143] round_filter input=1280 output=2304
# I0816 14:53:14.139702 139769975768896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0816 14:53:14.184396 139769975768896 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0816 14:53:14.184488 139769975768896 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0816 14:53:14.184525 139769975768896 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0816 14:53:14.185323 139769975768896 efficientnet_model.py:143] round_filter input=32 output=64
# I0816 14:53:14.195103 139769975768896 efficientnet_model.py:143] round_filter input=32 output=64
# I0816 14:53:14.195177 139769975768896 efficientnet_model.py:143] round_filter input=16 output=32
# I0816 14:53:14.324660 139769975768896 efficientnet_model.py:143] round_filter input=16 output=32
# I0816 14:53:14.324753 139769975768896 efficientnet_model.py:143] round_filter input=24 output=48
# I0816 14:53:14.593220 139769975768896 efficientnet_model.py:143] round_filter input=24 output=48
# I0816 14:53:14.593314 139769975768896 efficientnet_model.py:143] round_filter input=40 output=80
# I0816 14:53:14.860003 139769975768896 efficientnet_model.py:143] round_filter input=40 output=80
# I0816 14:53:14.860099 139769975768896 efficientnet_model.py:143] round_filter input=80 output=160
# I0816 14:53:15.236923 139769975768896 efficientnet_model.py:143] round_filter input=80 output=160
# I0816 14:53:15.237015 139769975768896 efficientnet_model.py:143] round_filter input=112 output=224
# I0816 14:53:15.616039 139769975768896 efficientnet_model.py:143] round_filter input=112 output=224
# I0816 14:53:15.616132 139769975768896 efficientnet_model.py:143] round_filter input=192 output=384
# I0816 14:53:16.100124 139769975768896 efficientnet_model.py:143] round_filter input=192 output=384
# I0816 14:53:16.100214 139769975768896 efficientnet_model.py:143] round_filter input=320 output=640
# I0816 14:53:16.258464 139769975768896 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0816 14:53:16.275953 139769975768896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 10.78s
# I0816 14:53:16.326489 139769975768896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 10.78s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0816 14:53:16.339084 139769975768896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0816 14:53:16.339976 139769975768896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0816 14:53:16.340203 139769975768896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0816 14:53:16.340758 139769975768896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0816 14:53:16.341273 139769975768896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0816 14:53:16.341440 139769975768896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0816 14:53:16.342065 139769975768896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 13.986s
#
# OK (skipped=1)

# %%
# !pip install tensorflow --upgrade

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2023-08-16 14:53:44--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.251.140.16, 2a00:1450:4017:813::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.251.140.16|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46042990 (44M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_32 100%[===================>]  43.91M  5.12MB/s    in 9.1s
#
# 2023-08-16 14:53:54 (4.81 MB/s) - ‘ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz’ saved [46042990/46042990]
#
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ssd_mobilenet_v2_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'ThumbsUp', 'id':1}, {'name':'ThumbsDown', 'id':2}, {'name':'ThankYou', 'id':3}, {'name':'LiveLong', 'id':4}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python corrected_generate_tfrecord.py -x Tensorflow/labelimg/train -l Tensorflow/workspace/annotation/label_map.pbtxt -o Tensorflow/workspace/annotation/train.record
# !python corrected_generate_tfrecord.py -x Tensorflow/labelimg/test -l Tensorflow/workspace/annotation/label_map.pbtxt -o Tensorflow/workspace/annotation/test.record
# Out:
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Successfully created the TFRecord file: Tensorflow/workspace/annotation/train.record
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Successfully created the TFRecord file: Tensorflow/workspace/annotation/test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
# /bin/bash: /home/n0name/miniconda3/envs/tft/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': center_net {
#    num_classes: 2
#    feature_extractor {
#      type: "resnet_v1_50_fpn"
#    }
#    image_resizer {
#      keep_aspect_ratio_resizer {
#        min_dimension: 512
#        max_dimension: 512
#        pad_to_max_dimension: true
#      }
#    }
#    object_detection_task {
#      task_loss_weight: 1.0
#      offset_loss_weight: 1.0
#      scale_loss_weight: 0.10000000149011612
#      localization_loss {
#        l1_localization_loss {
#        }
#      }
#    }
#    object_center_params {
#      object_center_loss_weight: 1.0
#      classification_loss {
#        penalty_reduced_logistic_focal_loss {
#          alpha: 2.0
#          beta: 4.0
#        }
#      }
#      min_box_overlap_iou: 0.699999988079071
#      max_box_predictions: 100
#    }
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_aspect_ratio: 0.5
#      max_aspect_ratio: 1.7000000476837158
#      random_coef: 0.25
#    }
#  }
#  data_augmentation_options {
#    random_adjust_hue {
#    }
#  }
#  data_augmentation_options {
#    random_adjust_contrast {
#    }
#  }
#  data_augmentation_options {
#    random_adjust_saturation {
#    }
#  }
#  data_augmentation_options {
#    random_adjust_brightness {
#    }
#  }
#  data_augmentation_options {
#    random_absolute_pad_image {
#      max_height_padding: 200
#      max_width_padding: 200
#      pad_color: 0.0
#      pad_color: 0.0
#      pad_color: 0.0
#    }
#  }
#  optimizer {
#    adam_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.0010000000474974513
#          total_steps: 250000
#          warmup_learning_rate: 0.0002500000118743628
#          warmup_steps: 5000
#        }
#      }
#      epsilon: 1.0000000116860974e-07
#    }
#    use_moving_average: false
#  }
#  num_steps: 250000
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "Tensorflow/workspace/annotation/label_map.pbtxt"
#  tf_record_input_reader {
#    input_path: "Tensorflow/workspace/annotation/train.record"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false
#  batch_size: 1,
#  'eval_input_configs': [label_map_path: "Tensorflow/workspace/annotation/label_map.pbtxt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "Tensorflow/workspace/annotation/test.record"
#  }
#  ],
#  'eval_input_config': label_map_path: "Tensorflow/workspace/annotation/label_map.pbtxt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "Tensorflow/workspace/annotation/test.record"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/TESTING --pipeline_config_path=Tensorflow/workspace/models/TESTING/pipeline.config --num_train_steps=2000

# %%
# !{command}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format('Tensorflow/models/research/object_detection/model_main_tf2.py', paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/model_for_TFT --pipeline_config_path=Tensorflow/workspace/models/model_for_TFT/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/model_for_TFT

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util
# Out:
# 2023-08-22 23:30:53.502210: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-22 23:30:53.526581: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-22 23:30:54.007630: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-21')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections
# Out:
# 2023-08-22 23:31:17.924487: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: UNKNOWN ERROR (100)

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', '74e577d2-4102-11ee-a2c7-a7fbcabc69c4.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
img = cv2.resize(img, (640, 360))
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=25,
            min_score_thresh=.5,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %%
from tensorflow.keras import backend as K
K.clear_session()

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
